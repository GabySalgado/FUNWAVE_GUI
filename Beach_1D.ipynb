# %% [markdown]
# This Notebook runs simple one-dimensional FUNWAVE simulations.
# -----
#
# It consists of the following four steps:
#
# * **Step #1** - Bathymetry: In this step you can generate the one-dimensional bathymetry that will be used in the FUNWAVE simulation. The user has the option of creating a flat bathymetry, a slope bathymetry or upload his own file. Once the depth file is generated, proceed to Step #2.
#
# * **Step #2** - Input File: In this tab you can generate the Input file with your desired specifications for the simulation. After generating your input file, proceed to Step #3.
#
# * **Step #3** - Run Funwave: This tab lets you run FUNWAVE without the need of a terminal. You can also see the simulation's proggress and abort it if it is necessary. Proceed to Step #4 to process your results.
#
# * **Step #4** - Post Processing: This tab gives you the option of generating an image at an specific time or generate a video of the simulation.

# %%
##### %matplotlib inline
#%matplotlib notebook
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output

# import project title and generate project button from PRINCIPAL_TAB 
# once the button is pressed, the entire GUI will appear
# the function that does this is located at wavemaker_Function.py
from pyFiles2.PRINCIPAL_TAB import container_title,space_box2, project_button

display(space_box2,container_title,space_box2) # display project text box and button

############################        
#### Activate Functions ####
############################

from pyFiles2.wavemaker_Function import project_clicked # import generate project project fucntions

from pyFiles2.bathymetry_Functions import compute_high_difference, on_save_clicked, on_plot_clicked
# ^ import generate bathymetry functions

from pyFiles2.wavemaker_Function import toggle_choose_bathy # activate bathy type variables
from pyFiles2.wavemaker_Function import toggle_initial   # activate initial conditions input variables   
from pyFiles2.wavemaker_Function import update_initial_conditions # activate generate inintial condition files button  
from pyFiles2.wavemaker_Function import toggle_waveMaker # activate wavemaker variables
from pyFiles2.wavemaker_Function import toggle_DifSponge # activate diffusion sponge variables
from pyFiles2.wavemaker_Function import toggle_FricSponge # activate friction sponge variables
from pyFiles2.wavemaker_Function import toggle_DirSponge # activate direct sponge variables
from pyFiles2.wavemaker_Function import toggle_waveH # activate Wave Height Output variables

from pyFiles2.input_Functions import update_input_function # activate update input values button
from pyFiles2.input_Functions import boolean_function # activate generate input file button

# activate the output variables (located in PrincipalTab_3) that will be shown the post-process list:
from pyFiles2.output_functions import toggle_output_ETA
from pyFiles2.output_functions import toggle_output_U
from pyFiles2.output_functions import toggle_output_V
from pyFiles2.output_functions import toggle_output_Hmax
from pyFiles2.output_functions import toggle_output_Hmin
from pyFiles2.output_functions import toggle_output_MFmax
from pyFiles2.output_functions import toggle_output_Umax
from pyFiles2.output_functions import toggle_output_VORmax
from pyFiles2.output_functions import toggle_output_Umean
from pyFiles2.output_functions import toggle_output_Vmean
from pyFiles2.output_functions import toggle_output_ETAmean
from pyFiles2.output_functions import toggle_output_MASK
from pyFiles2.output_functions import toggle_output_MASK9
from pyFiles2.output_functions import toggle_output_SourceX
from pyFiles2.output_functions import toggle_output_SourceY
from pyFiles2.output_functions import toggle_output_P
from pyFiles2.output_functions import toggle_output_Q
from pyFiles2.output_functions import toggle_output_Fy
from pyFiles2.output_functions import toggle_output_Fx
from pyFiles2.output_functions import toggle_output_Gy
from pyFiles2.output_functions import toggle_output_Gx
from pyFiles2.output_functions import toggle_output_AGE
from pyFiles2.output_functions import toggle_choose_output


from pyFiles2.video_Functions import runVID_function,saveSurface_clicked, plotSurface_clicked
# ^ activate post processing buttons

#from pyFiles2.funwave_Functions import runFUN_function
#RunFunwave_button.on_click(runFUN_function)        # activate run funwave button 

#from pyFiles2.funwave_Functions import abortFun_function
#abortFun_button.on_click(abortFun_function)        # activate abort funwave button
